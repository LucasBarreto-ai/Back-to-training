# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'Nome': ['Lucas', 'Barreto'],
                      'Idade': [28, 30]})

# %%
df[df['Idade'] >= 30]
# Out:
#       Nome  Idade
# 1  Barreto     30

# %%
df = df.rename(columns={'Idade': 'Anos de vida'})

# %%
df.columns = ['Nome dado', 'Idade']

# %%
df['email'] = ['LUCASbarRetO2025@OUTlook.COm', 'baRRETOlucas29@gMAIL.com']

# %%
df['email'] = pd.Series(df['email']).astype(str)

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df['email'] = df['email'].astype(str)

# %%
df = pd.DataFrame(df)

# %%
df.loc[len(df), "Nome dado"] = "Padre Quemedo"

# %%
novos = pd.DataFrame({
    'Nome dado': ['Cuscuzante', 'Debufante Forup']
})

# %%
df = pd.concat([df, novos], ignore_index=True)
df.drop(index=[3, 4])
# Out:
#                                                e-mail        Nome dado
# 0                        lucasbarreto2025@outlook.com              nan
# 1                            barretolucas29@gmail.com              nan
# 2   0    LUCASbarRetO2025@OUTlook.COm
# 1        baR...              nan
# 5                                                 NaN    Padre Quemedo
# 6                                                 NaN    Padre Quemedo
# 7                                                 NaN       Cuscuzante
# 8                                                 NaN  Debufante Forup
# 9                                                 NaN       Cuscuzante
# 10                                                NaN  Debufante Forup
# 11                                                NaN       Cuscuzante
# 12                                                NaN  Debufante Forup
# 13                                                NaN       Cuscuzante
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.dropna(subset=['e-mail'])

# %%
df.dropna()
# Out:
#                                               e-mail Nome dado
# 0                       lucasbarreto2025@outlook.com       nan
# 1                           barretolucas29@gmail.com       nan
# 2  0    LUCASbarRetO2025@OUTlook.COm
# 1        baR...       nan

# %%
df = df.drop(columns=['Nome dado'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 df = df.drop(columns=['Nome dado'])
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
df = df.drop_duplicates()
df.value_counts # Não tem ()
df.unique() # Só funciona em DataFrame, assim como o nunique (que exibe a quantidade de valores únicos)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10796\3335301987.py in ?()
#       1 df = df.drop_duplicates()
#       2 df.value_counts # Não tem ()
# ----> 3 df.unique() # Só funciona em DataFrame, assim como o nunique (que exibe a quantidade de valores únicos)
#
# ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df['Nome'] = ['Lucas', 'Gui', 'Socorro']

# %%
df['Salario'] = [5500, 7500, 4500]

# %%
df['Salario_Anual'] = df['Salario'] * 12

# %%
df = df.rename(columns={'e-mail': 'E-mail'})
df['E-mail'] = df['E-mail'].str.lower()

# %%
df['E-mail'] = df['E-mail'].fillna('socorrobarreto12@gmail.com')

# %%
df
# Out:
#                          E-mail     Nome  Salario  Salario_Anual
# 0  lucasbarreto2025@outlook.com    Lucas     5500          66000
# 1      barretolucas29@gmail.com      Gui     7500          90000
# 2    socorrobarreto12@gmail.com  Socorro     4500          54000
